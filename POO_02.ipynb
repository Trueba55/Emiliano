# %% [markdown]
# #Diccionarios

# %%
Antonio = {"Antonio": [9.5,1.76,20,1]}

# %%
type(Antonio)
# Out:
# dict

# %%
POOUP = {"Antonio": [9.5,1.76,20,1],
        "Alejandra": [9.2,1.60,21,1],
        "Manuel": [9.2,1.77,21,1],
        "Daniela": [9.3,1.58,21,2],
        "Eduardo": [9.0,1.72,20,0 ],
        "Sofia":[9.2,1.75,21,1] }

# %%
print(POOUP)
# Out:
# {'Antonio': [9.5, 1.76, 20, 1], 'Alejandra': [9.2, 1.6, 21, 1], ' Manuel ': [9.2, 1.77, 21, 1], 'Daniela ': [9.3, 1.58, 21, 2], 'Farca ': [9.2, 1.75, 21, 1], 'Sofia ': [9.2, 1.75, 21, 1]}

# %%
# Importamos al módulo Pandas #
import pandas as pd

# %%
Alumnos = pd.DataFrame(POOUP)
Alumnos
# Out:
#    Antonio  Alejandra  Manuel  Daniela  Eduardo  Sofia
# 0     9.50        9.2    9.20     9.30     9.00   9.20
# 1     1.76        1.6    1.77     1.58     1.72   1.75
# 2    20.00       21.0   21.00    21.00    20.00  21.00
# 3     1.00        1.0    1.00     2.00     0.00   1.00

# %%
type(Alumnos)
# Out:
# pandas.core.frame.DataFrame

# %%
Alumnos.ndim # Dimension como objeto en Python
# Out:
# 2

# %%
Alumnos["Eduardo"]
# Out:
# 0     9.00
# 1     1.72
# 2    20.00
# 3     0.00
# Name: Eduardo, dtype: float64

# %%
Alumnos[["Eduardo","Sofia"]]
# Out:
#    Eduardo  Sofia
# 0     9.00   9.20
# 1     1.72   1.75
# 2    20.00  21.00
# 3     0.00   1.00

# %%
Alumnos.iloc[0:2] #Rebana la base de datos del primer renglon
                  # al segundo
# Out:
#    Antonio  Alejandra  Manuel  Daniela  Eduardo  Sofia
# 0     9.50        9.2    9.20     9.30     9.00   9.20
# 1     1.76        1.6    1.77     1.58     1.72   1.75
